# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/federated_models/
# Out:
# accuracy_initial_vs_final.png  cross_eval_accuracy.png	model_A.h5  model_B.h5

# %%
from tensorflow.keras.models import load_model

model_A = load_model("/content/drive/MyDrive/federated_models/model_A.h5")
model_B = load_model("/content/drive/MyDrive/federated_models/model_B.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1./255)

test_gen_A = datagen.flow_from_directory(
    "/content/drive/MyDrive/my_processed_data/test",
    target_size=(224,224),
    color_mode="grayscale",
    batch_size=32,
    class_mode="binary",
    shuffle=False
)

test_gen_B = datagen.flow_from_directory(
    "/content/drive/MyDrive/test",
    target_size=(224,224),
    color_mode="grayscale",
    batch_size=32,
    class_mode="binary",
    shuffle=False
)
# Out:
# Found 624 images belonging to 2 classes.
# Found 1172 images belonging to 2 classes.

# %%
print("Model A on Dataset A")
model_A.evaluate(test_gen_A)

print("Model B on Dataset B")
model_B.evaluate(test_gen_B)
# Out:
# Model A on Dataset A
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 105s 5s/step - accuracy: 0.7644 - loss: 1.1881
# Model B on Dataset B
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 287s 8s/step - accuracy: 0.9309 - loss: 0.1580
# [0.15804843604564667, 0.9308874011039734]

# %%
print("Model A on Dataset B")
model_A.evaluate(test_gen_B)

print("Model B on Dataset A")
model_B.evaluate(test_gen_A)
# Out:
# Model A on Dataset B
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - accuracy: 0.9718 - loss: 0.0681
# Model B on Dataset A
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.9087 - loss: 0.2149
# [0.2148955911397934, 0.9086538553237915]

# %%
from tensorflow.keras import layers, models

def create_model():
    model = models.Sequential()

    model.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(224,224,1)))
    model.add(layers.MaxPooling2D(2,2))

    model.add(layers.Conv2D(64, (3,3), activation='relu'))
    model.add(layers.MaxPooling2D(2,2))
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(128, (3,3), activation='relu'))
    model.add(layers.MaxPooling2D(2,2))
    model.add(layers.Dropout(0.4))

    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.5))

    model.add(layers.Dense(1, activation='sigmoid'))

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
weights_A = model_A.get_weights()
weights_B = model_B.get_weights()

# %%
import numpy as np

weights_A = model_A.get_weights()
weights_B = model_B.get_weights()

avg_weights = []

for wA, wB in zip(weights_A, weights_B):
    avg_weights.append((wA + wB) / 2)

# %%
global_model = create_model()
global_model.set_weights(avg_weights)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
print("Global Model on Dataset A")
global_model.evaluate(test_gen_A)

print("Global Model on Dataset B")
global_model.evaluate(test_gen_B)
# Out:
# Global Model on Dataset A
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.3814 - loss: 0.7020
# Global Model on Dataset B
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.2995 - loss: 0.7132
# [0.713222861289978, 0.2994880676269531]

# %%
model_A.set_weights(global_model.get_weights())
model_B.set_weights(global_model.get_weights())

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1./255)

train_gen_A = datagen.flow_from_directory(
    "/content/drive/MyDrive/my_processed_data/train",
    target_size=(224,224),
    color_mode="grayscale",
    batch_size=32,
    class_mode="binary"
)

train_gen_B = datagen.flow_from_directory(
    "/content/drive/MyDrive/train",
    target_size=(224,224),
    color_mode="grayscale",
    batch_size=32,
    class_mode="binary"
)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 4684 images belonging to 2 classes.

# %%
model_A.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model_A.fit(train_gen_A, epochs=20)
# Out:
# Epoch 1/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 360s 2s/step - accuracy: 0.9494 - loss: 0.1228
# Epoch 2/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 22s 136ms/step - accuracy: 0.9720 - loss: 0.0766
# Epoch 3/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 21s 129ms/step - accuracy: 0.9758 - loss: 0.0680
# Epoch 4/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 22s 134ms/step - accuracy: 0.9739 - loss: 0.0675
# Epoch 5/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 21s 130ms/step - accuracy: 0.9822 - loss: 0.0445
# Epoch 6/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 21s 130ms/step - accuracy: 0.9793 - loss: 0.0563
# Epoch 7/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 21s 130ms/step - accuracy: 0.9824 - loss: 0.0420
# Epoch 8/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - accuracy: 0.9889 - loss: 0.0306
# Epoch 9/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 21s 131ms/step - accuracy: 0.9879 - loss: 0.0347
# Epoch 10/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 21s 128ms/step - accuracy: 0.9887 - loss: 0.0327
# Epoch 11/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 22s 134ms/step - accuracy: 0.9925 - loss: 0.0201
# Epoch 12/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 21s 128ms/step - accuracy: 0.9875 - loss: 0.0313
# Epoch 13/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 22s 133ms/step - accuracy: 0.9939 - loss: 0.0175
# Epoch 14/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 21s 130ms/step - accuracy: 0.9898 - loss: 0.0265
# Epoch 15/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 21s 131ms/step - accuracy: 0.9944 - loss: 0.0128
# Epoch 16/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 41s 132ms/step - accuracy: 0.9923 - loss: 0.0238
# Epoch 17/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 21s 131ms/step - accuracy: 0.9935 - loss: 0.0198
# Epoch 18/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.9904 - loss: 0.0279
# Epoch 19/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 21s 131ms/step - accuracy: 0.9962 - loss: 0.0100
# Epoch 20/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 21s 130ms/step - accuracy: 0.9948 - loss: 0.0174

# %%
print("Model A on Dataset A")
loss_AA, acc_AA = model_A.evaluate(test_gen_A)
# Out:
# Model A on Dataset A
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.7612 - loss: 2.2581

# %%
model_B.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model_B.fit(train_gen_B, epochs=20)
# Out:
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1180s 8s/step - accuracy: 0.9246 - loss: 0.1905
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9473 - loss: 0.1380
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9560 - loss: 0.1170
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 19s 131ms/step - accuracy: 0.9605 - loss: 0.1060
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 19s 132ms/step - accuracy: 0.9669 - loss: 0.0887
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 20s 133ms/step - accuracy: 0.9675 - loss: 0.0824
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 19s 132ms/step - accuracy: 0.9725 - loss: 0.0716
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 19s 131ms/step - accuracy: 0.9742 - loss: 0.0669
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9750 - loss: 0.0703
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 20s 135ms/step - accuracy: 0.9778 - loss: 0.0597
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 19s 130ms/step - accuracy: 0.9797 - loss: 0.0522
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 19s 127ms/step - accuracy: 0.9825 - loss: 0.0471
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 19s 131ms/step - accuracy: 0.9842 - loss: 0.0403
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 19s 131ms/step - accuracy: 0.9851 - loss: 0.0419
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9878 - loss: 0.0340
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9878 - loss: 0.0324
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9874 - loss: 0.0335
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 19s 127ms/step - accuracy: 0.9889 - loss: 0.0296
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 20s 135ms/step - accuracy: 0.9906 - loss: 0.0235
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 19s 131ms/step - accuracy: 0.9898 - loss: 0.0254

# %%
print("Model B on Dataset B")
loss_BB, acc_BB = model_B.evaluate(test_gen_B)
# Out:
# Model B on Dataset B
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - accuracy: 0.9505 - loss: 0.1933

# %%
print("Model A on Dataset B")
loss_AB, acc_AB = model_A.evaluate(test_gen_B)

print("Model B on Dataset A")
loss_BA, acc_BA = model_B.evaluate(test_gen_A)
# Out:
# Model A on Dataset B
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 0.9795 - loss: 0.0616
# Model B on Dataset A
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.9712 - loss: 0.0691

# %%
weights_A_1 = model_A.get_weights()
weights_B_1 = model_B.get_weights()

# %%
avg_weights = []

for wA, wB in zip(weights_A_1, weights_B_1):
    avg_weights.append((wA + wB) / 2)

# %%
global_model = create_model()
global_model.set_weights(avg_weights)

# %%
# Reset before each evaluation
test_gen_A.reset()
test_gen_B.reset()

# %%
print("Global Model on Dataset A")
global_model.evaluate(test_gen_A)

print("Global Model on Dataset B")
global_model.evaluate(test_gen_B)
# Out:
# Global Model on Dataset A
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.8638 - loss: 0.4347
# Global Model on Dataset B
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 0.9684 - loss: 0.0999
# [0.09992504864931107, 0.9684300422668457]

# %% [markdown]
# **Checking Models individually with final Updated weights**

# %%
model_A.set_weights(global_model.get_weights())
model_B.set_weights(global_model.get_weights())

# %%
print("Model A on Dataset A")
model_A.evaluate(test_gen_A)

print("Model B on Dataset B")
model_B.evaluate(test_gen_B)
# Out:
# Model A on Dataset A
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 0.8638 - loss: 0.4347
# Model B on Dataset B
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9684 - loss: 0.0999
# [0.09992504864931107, 0.9684300422668457]

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# ─────────────────────────────────────────────
# DATA FROM NOTEBOOK OUTPUTS (Model3.ipynb)
# ─────────────────────────────────────────────

# ── Initial models (before FL) ──
init_acc = {
    "Model A on Dataset A": 0.7612,
    "Model A on Dataset B": 0.9795,
    "Model B on Dataset A": 0.9712,
    "Model B on Dataset B": 0.9505,
}
init_loss = {
    "Model A on Dataset A": 2.2581,
    "Model A on Dataset B": 0.0616,
    "Model B on Dataset A": 0.0691,
    "Model B on Dataset B": 0.1933,
}

# ── After FL (final round global model) ──
final_acc = {
    "Model A (FL) on Dataset A": 0.8638,
    "Model A (FL) on Dataset B": 0.9684,   # same weights as global
    "Model B (FL) on Dataset A": 0.8638,   # same weights as global
    "Model B (FL) on Dataset B": 0.9684,
}
final_loss = {
    "Model A (FL) on Dataset A": 0.4347,
    "Model A (FL) on Dataset B": 0.0999,
    "Model B (FL) on Dataset A": 0.4347,
    "Model B (FL) on Dataset B": 0.0999,
}

# ─────────────────────────────────────────────
# COLOR PALETTE
# ─────────────────────────────────────────────
C_A_INIT  = "#4C72B0"   # Model A initial – blue
C_B_INIT  = "#DD8452"   # Model B initial – orange
C_A_FL    = "#55A868"   # Model A after FL – green
C_B_FL    = "#C44E52"   # Model B after FL – red

# %%
fig, ax = plt.subplots(figsize=(9, 5))

models     = ["Model A\n(on Dataset A)", "Model B\n(on Dataset B)"]
acc_before = [init_acc["Model A on Dataset A"],  init_acc["Model B on Dataset B"]]
acc_after  = [final_acc["Model A (FL) on Dataset A"], final_acc["Model B (FL) on Dataset B"]]

x   = np.arange(len(models))
w   = 0.35

b1 = ax.bar(x - w/2, acc_before, w, label="Before FL (Initial Model)", color=[C_A_INIT, C_B_INIT], edgecolor="white", linewidth=1.2)
b2 = ax.bar(x + w/2, acc_after,  w, label="After FL  (Final Model)",   color=[C_A_FL,   C_B_FL],   edgecolor="white", linewidth=1.2)

for bar in list(b1) + list(b2):
    ax.annotate(f"{bar.get_height():.4f}",
                xy=(bar.get_x() + bar.get_width() / 2, bar.get_height()),
                xytext=(0, 4), textcoords="offset points",
                ha='center', va='bottom', fontsize=9, fontweight='bold')

ax.set_xticks(x)
ax.set_xticklabels(models, fontsize=11)
ax.set_ylabel("Accuracy", fontsize=11)
ax.set_title("Accuracy on Own Test Data — Before vs After Federated Learning", fontsize=12, fontweight='bold', pad=12)
ax.set_ylim(0, 1.12)
ax.axhline(1.0, color='grey', linewidth=0.6, linestyle='--', alpha=0.5)
ax.legend(fontsize=10)
ax.spines[['top', 'right']].set_visible(False)
plt.tight_layout()
plt.savefig("graph1_own_test_accuracy.png", dpi=150)
plt.show()
print("Saved: graph1_own_test_accuracy.png")



fig, ax = plt.subplots(figsize=(12, 5.5))

categories  = ["A on A", "A on B", "B on A", "B on B"]
before_vals = [
    init_acc["Model A on Dataset A"],
    init_acc["Model A on Dataset B"],
    init_acc["Model B on Dataset A"],
    init_acc["Model B on Dataset B"],
]
after_vals = [
    final_acc["Model A (FL) on Dataset A"],
    final_acc["Model A (FL) on Dataset B"],
    final_acc["Model B (FL) on Dataset A"],
    final_acc["Model B (FL) on Dataset B"],
]

x2 = np.arange(len(categories))
colors_before = [C_A_INIT, C_A_INIT, C_B_INIT, C_B_INIT]
colors_after  = [C_A_FL,   C_A_FL,   C_B_FL,   C_B_FL]

b1 = ax.bar(x2 - w/2, before_vals, w, label="Before FL", color=colors_before, edgecolor="white", linewidth=1.2, alpha=0.85)
b2 = ax.bar(x2 + w/2, after_vals,  w, label="After FL",  color=colors_after,  edgecolor="white", linewidth=1.2)

for bar in list(b1) + list(b2):
    ax.annotate(f"{bar.get_height():.4f}",
                xy=(bar.get_x() + bar.get_width() / 2, bar.get_height()),
                xytext=(0, 4), textcoords="offset points",
                ha='center', va='bottom', fontsize=8.5, fontweight='bold')

ax.set_xticks(x2)
ax.set_xticklabels([f"Model {c}" for c in categories], fontsize=11)
ax.set_ylabel("Accuracy", fontsize=11)
ax.set_title("Cross-Evaluation Accuracy — Before vs After Federated Learning", fontsize=12, fontweight='bold', pad=12)
ax.set_ylim(0, 1.14)
ax.axhline(1.0, color='grey', linewidth=0.6, linestyle='--', alpha=0.5)

# Custom legend
patch_A_i = mpatches.Patch(color=C_A_INIT, label="Model A – Before FL")
patch_B_i = mpatches.Patch(color=C_B_INIT, label="Model B – Before FL")
patch_A_f = mpatches.Patch(color=C_A_FL,   label="Model A – After FL")
patch_B_f = mpatches.Patch(color=C_B_FL,   label="Model B – After FL")
ax.legend(handles=[patch_A_i, patch_B_i, patch_A_f, patch_B_f], fontsize=9, ncol=2)
ax.spines[['top', 'right']].set_visible(False)
plt.tight_layout()
plt.savefig("graph3_cross_eval_accuracy.png", dpi=150)
plt.show()
print("Saved: graph3_cross_eval_accuracy.png")
# Out:
# Saved: graph1_own_test_accuracy.png
# Saved: graph3_cross_eval_accuracy.png
